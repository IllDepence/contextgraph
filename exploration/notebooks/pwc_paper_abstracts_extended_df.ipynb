# %%
import datetime
import os
import json
import random
import re
import regex
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('/home/ws/ys8950/dev/data/paperswithcode/data/papers-with-abstracts-extended.json') as f:
    df_paper_abstracts_extended = pd.DataFrame(json.load(f))
with open('/home/ws/ys8950/dev/data/paperswithcode/data/methods.json') as f:
    df_methods = pd.DataFrame(json.load(f))
with open('/home/ws/ys8950/dev/data/paperswithcode/data/datasets.json') as f:
    df_datasets = pd.DataFrame(json.load(f))

# %%
print('- - - - - paper_abstracts columns - - - - - -')
print(df_paper_abstracts_extended.columns.to_list())
print('- - - - - methods dicts - - - - - -')
print(list(df_paper_abstracts_extended[
    df_paper_abstracts_extended['methods'].apply(lambda x: len(x)) > 0
].iloc[0].methods[0].keys()))
print('- - - - - dataset dicts - - - - - -')
print(list(df_paper_abstracts_extended[
    df_paper_abstracts_extended['datasets'].apply(lambda x: len(x)) > 0
].iloc[0].datasets[0].keys()))
print('- - - - - method columns - - - - - -')
print(df_methods.columns.to_list())
print('- - - - - dataset columns - - - - - -')
print(df_datasets.columns.to_list())
# Out:
# - - - - - paper_abstracts columns - - - - - -
# ['paper_url', 'arxiv_id', 'title', 'abstract', 'url_abs', 'url_pdf', 'proceeding', 'authors', 'tasks', 'date', 'methods', 'datasets']
# - - - - - methods dicts - - - - - -
# ['name', 'full_name', 'description', 'introduced_year', 'source_url', 'source_title', 'code_snippet_url', 'main_collection']
# - - - - - dataset dicts - - - - - -
# ['url', 'name', 'full_name', 'homepage', 'description', 'paper', 'introduced_date', 'warning', 'modalities', 'tasks', 'languages', 'variants', 'num_papers', 'data_loaders']
# - - - - - method columns - - - - - -
# ['url', 'name', 'full_name', 'description', 'paper', 'introduced_year', 'source_url', 'source_title', 'code_snippet_url', 'collections']
# - - - - - dataset columns - - - - - -
# ['url', 'name', 'full_name', 'homepage', 'description', 'paper', 'introduced_date', 'warning', 'modalities', 'tasks', 'languages', 'variants', 'num_papers', 'data_loaders']

# %% [markdown]
# ### Create easily accessible "paper usage" records for data sets and methods

# %%
def paper_df_or_row_to_dict(paper_df):
    """ Create a slightly stripped down dict version of a paper dataframe row
    
        (strips datasets and methods column)
    """
    
    keep_columns = [
        'paper_url', 'arxiv_id', 'title', 'abstract', 'url_abs', # all but methods and data sets
        'url_pdf', 'proceeding', 'authors', 'tasks', 'date'
    ]
    if type(paper_df) == pd.DataFrame:
        if paper_df.shape[0] == 0:
            return None
        assert (paper_df.shape[0] == 1), 'paper URL not unique'
        paper_dict = paper_df[
            keep_columns
        ].iloc[0].to_dict()
    elif type(paper_df) == pd.Series:
        paper_dict = dict()
        for col in keep_columns:
            paper_dict[col] = paper_df[col]
    else:
        raise
     
    return paper_dict


datasets = dict()
methods = dict()
for idx, ppr in df_paper_abstracts_extended.iterrows():
    current_paper_dict = paper_df_or_row_to_dict(ppr)
    for m in ppr.methods:
        if m['full_name'] not in methods:
            # initialize method dict
            meth_dict = m.copy()
            # add extra data if retrievable
            extra_data = df_methods[df_methods.full_name == m['full_name']]
            if extra_data.shape[0] == 0:  # method name not in methods dataframe
                intro_paper_dict = None
            else:
                # assert (extra_data.shape[0] == 1), 'method name not unique'
                # ↑ violated by e.g. Differentiable Neural Architecture Search
                extra_dict = extra_data.iloc[0].to_dict()  # just take the first
                meth_dict.update(extra_dict)
                if meth_dict['paper'] is not None:  # 'paper' only in extra data, therefore in else part
                    intro_paper = df_paper_abstracts_extended[
                        df_paper_abstracts_extended.paper_url == 'https://paperswithcode.com/paper/' + meth_dict['paper']
                    ]
                    intro_paper_dict = paper_df_or_row_to_dict(intro_paper)
            methods[m['full_name']] = {
                'pwc_data': meth_dict,
                'intro_paper': intro_paper_dict,
                'using_papers': []
            }
        # add info on current paper
        methods[m['full_name']]['using_papers'].append(current_paper_dict)
    for d in ppr.datasets:
        if d['url'] not in datasets:
            # initialize dataset dict
            data_dict = d.copy()
            datasets[d['url']] = {
                'pwc_data': data_dict,
                'using_papers': []
            }
        # add info on current paper
        datasets[d['url']]['using_papers'].append(current_paper_dict)

# %%
# for name, method in methods.items():
#     print(name)
#     for ppr in method['using_papers']:
#         print(ppr['date'])
# for url, dataset in datasets.items():
#     print(dataset['pwc_data']['name'])
#     for ppr in dataset['using_papers']:
#         print(ppr['date'])

# %%
# with open('/home/ws/ys8950/dev/data/paperswithcode/data/methods_with_using_papers.json', 'w') as f:
#     json.dump(methods, f)
# with open('/home/ws/ys8950/dev/data/paperswithcode/data/datasets_with_using_papers.json', 'w') as f:
#     json.dump(datasets, f)

# %% [markdown]
# ### Starting from papers with joint data set & method use, create usage records

# %%
df_methdata_papers = df_paper_abstracts_extended[
    (df_paper_abstracts_extended['methods'].apply(lambda x: len(x)) > 0)
    &
    (df_paper_abstracts_extended['datasets'].apply(lambda x: len(x)) > 0)
]

# %%
combo_use_pairs = set()
for idx, row in df_methdata_papers.iterrows():
    ds = [d['url'] for d in row['datasets']]
    ms = [m['full_name'] for m in row['methods']]
    for d in ds:
        for m in ms:
            combo_use_pairs.add(f'{d}\t{m}')
combo_use_pairs = [p.split('\t') for p in combo_use_pairs]

# %%
def add_record_entry_data(rec_dict, ppr_type, ppr_dict, uses_meth=0, uses_data=0):
    if 'arxiv_id' in ppr_dict and ppr_dict['arxiv_id'] is not None:
        record_key = ppr_dict['arxiv_id']
    else:
        record_key = ppr_dict['paper_url']
    if record_key not in rec_dict:
        rec_dict[record_key] = {
            'type': ppr_type,  # intro papers always come first, so this won't be overwritten
            'date': ppr_dict['date'],
            'arxiv_id': ppr_dict['arxiv_id'],
            'uses_meth': uses_meth,
            'uses_data': uses_data
        }
    else:
        if uses_meth == 1:
            rec_dict[record_key]['uses_meth'] = 1
        elif uses_data == 1:
            rec_dict[record_key]['uses_data'] = 1
    # return not necessary b/c dicts are immutable


pair_records = dict()
for pair in combo_use_pairs:
    dataset_url = pair[0]
    method_full_name = pair[1]
    dataset_record = datasets[dataset_url]
    method_record = methods[method_full_name]
    pair_key = f'{dataset_record["pwc_data"]["name"]} + {method_record["pwc_data"]["full_name"]}'
    record_dict = dict()
    if method_record['intro_paper'] is not None:
        add_record_entry_data(
            record_dict,
            'intro',
            method_record['intro_paper'],
            uses_meth=1, 
            uses_data=0
        )
    for using_paper in method_record['using_papers']:
        add_record_entry_data(
            record_dict,
            'use',
            using_paper,
            uses_meth=1, 
            uses_data=0
        )
    for using_paper in dataset_record['using_papers']:
        add_record_entry_data(
            record_dict,
            'use',
            using_paper,
            uses_meth=0, 
            uses_data=1
        )
    pair_records[pair_key] = record_dict.copy()

# %%
# with open('/home/ws/ys8950/dev/software_campus/pwc-X-unarXive/combi_use_records.json', 'w') as f:
#     json.dump(pair_records, f)

# %% [markdown]
# ### Visualize / Analyze

# %%
random_pair = random.choice(list(pair_records.keys()))
print(random_pair)
pair_records[random_pair]

# TODO:
# - write visualization routine
#   - find nice example and manually play through
# - additionally link w/ unarXive citations
#   - extend visualization
# - consider adding full text contexts
# Out:
# ChestX-ray8 + Interpretability
# {'1804.03201': {'type': 'use',
#   'date': '2018-04-09',
#   'arxiv_id': '1804.03201',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.04820': {'type': 'use',
#   'date': '2018-06-13',
#   'arxiv_id': '1806.04820',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.08464': {'type': 'use',
#   'date': '2017-10-23',
#   'arxiv_id': '1710.08464',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.04555': {'type': 'use',
#   'date': '2018-06-12',
#   'arxiv_id': '1806.04555',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.04310': {'type': 'use',
#   'date': '2018-06-12',
#   'arxiv_id': '1806.04310',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.02199': {'type': 'use',
#   'date': '2018-06-06',
#   'arxiv_id': '1806.02199',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.01830': {'type': 'use',
#   'date': '2018-06-05',
#   'arxiv_id': '1806.01830',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.07658': {'type': 'use',
#   'date': '2018-03-20',
#   'arxiv_id': '1803.07658',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.00712': {'type': 'use',
#   'date': '2018-06-02',
#   'arxiv_id': '1806.00712',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.00578': {'type': 'use',
#   'date': '2018-06-02',
#   'arxiv_id': '1806.00578',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.00340': {'type': 'use',
#   'date': '2018-06-01',
#   'arxiv_id': '1806.00340',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.11191': {'type': 'use',
#   'date': '2018-04-30',
#   'arxiv_id': '1804.11191',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.10724': {'type': 'use',
#   'date': '2018-05-28',
#   'arxiv_id': '1805.10724',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.11571': {'type': 'use',
#   'date': '2018-05-29',
#   'arxiv_id': '1805.11571',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.08960': {'type': 'use',
#   'date': '2018-05-23',
#   'arxiv_id': '1805.08960',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.08012': {'type': 'use',
#   'date': '2018-02-22',
#   'arxiv_id': '1802.08012',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.07508': {'type': 'use',
#   'date': '2018-05-19',
#   'arxiv_id': '1805.07508',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.07468': {'type': 'use',
#   'date': '2018-05-18',
#   'arxiv_id': '1805.07468',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.06846': {'type': 'use',
#   'date': '2018-05-17',
#   'arxiv_id': '1805.06846',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.07233': {'type': 'use',
#   'date': '2018-05-17',
#   'arxiv_id': '1805.07233',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.00331': {'type': 'use',
#   'date': '2017-11-01',
#   'arxiv_id': '1711.00331',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.07519': {'type': 'use',
#   'date': '2018-03-20',
#   'arxiv_id': '1803.07519',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.04174': {'type': 'use',
#   'date': '2018-05-10',
#   'arxiv_id': '1805.04174',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.02917': {'type': 'use',
#   'date': '2018-05-08',
#   'arxiv_id': '1805.02917',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.10589': {'type': 'use',
#   'date': '2017-11-28',
#   'arxiv_id': '1711.10589',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.01889': {'type': 'use',
#   'date': '2018-05-03',
#   'arxiv_id': '1805.01889',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.01199': {'type': 'use',
#   'date': '2018-05-03',
#   'arxiv_id': '1805.01199',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.00632': {'type': 'use',
#   'date': '2018-05-02',
#   'arxiv_id': '1805.00632',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1805.00611': {'type': 'use',
#   'date': '2018-05-02',
#   'arxiv_id': '1805.00611',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.03067': {'type': 'use',
#   'date': '2018-03-08',
#   'arxiv_id': '1803.03067',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.08077': {'type': 'use',
#   'date': '2018-04-22',
#   'arxiv_id': '1804.08077',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.06620': {'type': 'use',
#   'date': '2018-04-18',
#   'arxiv_id': '1804.06620',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.05695': {'type': 'use',
#   'date': '2018-02-15',
#   'arxiv_id': '1802.05695',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1712.09707': {'type': 'use',
#   'date': '2017-12-27',
#   'arxiv_id': '1712.09707',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.04778': {'type': 'use',
#   'date': '2018-04-13',
#   'arxiv_id': '1804.04778',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.03368': {'type': 'use',
#   'date': '2018-04-10',
#   'arxiv_id': '1804.03368',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.02969': {'type': 'use',
#   'date': '2018-04-09',
#   'arxiv_id': '1804.02969',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.03240': {'type': 'use',
#   'date': '2018-03-28',
#   'arxiv_id': '1804.03240',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.08966': {'type': 'use',
#   'date': '2018-03-23',
#   'arxiv_id': '1803.08966',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.00399': {'type': 'use',
#   'date': '2017-11-01',
#   'arxiv_id': '1711.00399',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.07253': {'type': 'use',
#   'date': '2018-03-20',
#   'arxiv_id': '1803.07253',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.07102': {'type': 'use',
#   'date': '2018-03-19',
#   'arxiv_id': '1803.07102',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1712.02034': {'type': 'use',
#   'date': '2017-12-06',
#   'arxiv_id': '1712.02034',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.06589': {'type': 'use',
#   'date': '2018-03-18',
#   'arxiv_id': '1803.06589',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.07418': {'type': 'use',
#   'date': '2018-03-17',
#   'arxiv_id': '1803.07418',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.06010': {'type': 'use',
#   'date': '2018-03-15',
#   'arxiv_id': '1803.06010',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.05268': {'type': 'use',
#   'date': '2018-03-14',
#   'arxiv_id': '1803.05268',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.05036': {'type': 'use',
#   'date': '2018-03-13',
#   'arxiv_id': '1803.05036',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1801.08297': {'type': 'use',
#   'date': '2018-01-25',
#   'arxiv_id': '1801.08297',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.04967': {'type': 'use',
#   'date': '2018-03-13',
#   'arxiv_id': '1803.04967',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1801.07047': {'type': 'use',
#   'date': '2018-01-22',
#   'arxiv_id': '1801.07047',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.03544': {'type': 'use',
#   'date': '2018-03-09',
#   'arxiv_id': '1803.03544',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.03779': {'type': 'use',
#   'date': '2017-06-12',
#   'arxiv_id': '1706.03779',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1804.11177': {'type': 'use',
#   'date': '2018-03-08',
#   'arxiv_id': '1804.11177',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1803.01257': {'type': 'use',
#   'date': '2018-03-03',
#   'arxiv_id': '1803.01257',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.07839': {'type': 'use',
#   'date': '2018-02-21',
#   'arxiv_id': '1802.07839',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.07007': {'type': 'use',
#   'date': '2018-02-20',
#   'arxiv_id': '1802.07007',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1705.07368': {'type': 'use',
#   'date': '2017-05-20',
#   'arxiv_id': '1705.07368',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.01933': {'type': 'use',
#   'date': '2018-02-06',
#   'arxiv_id': '1802.01933',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.06259': {'type': 'use',
#   'date': '2018-02-17',
#   'arxiv_id': '1802.06259',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.06765': {'type': 'use',
#   'date': '2018-02-17',
#   'arxiv_id': '1802.06765',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.05998': {'type': 'use',
#   'date': '2018-02-16',
#   'arxiv_id': '1802.05998',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.00694': {'type': 'use',
#   'date': '2017-11-02',
#   'arxiv_id': '1711.00694',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.04346': {'type': 'use',
#   'date': '2018-02-12',
#   'arxiv_id': '1802.04346',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.05407': {'type': 'use',
#   'date': '2017-11-15',
#   'arxiv_id': '1711.05407',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.02952': {'type': 'use',
#   'date': '2018-02-08',
#   'arxiv_id': '1802.02952',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.00614': {'type': 'use',
#   'date': '2018-02-02',
#   'arxiv_id': '1802.00614',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.01274': {'type': 'use',
#   'date': '2018-02-05',
#   'arxiv_id': '1802.01274',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.00745': {'type': 'use',
#   'date': '2018-02-02',
#   'arxiv_id': '1802.00745',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1802.00560': {'type': 'use',
#   'date': '2018-02-02',
#   'arxiv_id': '1802.00560',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1801.09856': {'type': 'use',
#   'date': '2018-01-30',
#   'arxiv_id': '1801.09856',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.09121': {'type': 'use',
#   'date': '2017-08-30',
#   'arxiv_id': '1708.09121',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1801.06136': {'type': 'use',
#   'date': '2018-01-18',
#   'arxiv_id': '1801.06136',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1801.05091': {'type': 'use',
#   'date': '2018-01-16',
#   'arxiv_id': '1801.05091',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1612.03225': {'type': 'use',
#   'date': '2016-12-10',
#   'arxiv_id': '1612.03225',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.01467': {'type': 'use',
#   'date': '2017-10-04',
#   'arxiv_id': '1710.01467',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1801.01204': {'type': 'use',
#   'date': '2018-01-03',
#   'arxiv_id': '1801.01204',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.00811': {'type': 'use',
#   'date': '2017-10-02',
#   'arxiv_id': '1710.00811',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1712.03547': {'type': 'use',
#   'date': '2017-12-10',
#   'arxiv_id': '1712.03547',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1712.03779': {'type': 'use',
#   'date': '2017-12-08',
#   'arxiv_id': '1712.03779',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.08042': {'type': 'use',
#   'date': '2017-11-20',
#   'arxiv_id': '1711.08042',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1712.00576': {'type': 'use',
#   'date': '2017-12-02',
#   'arxiv_id': '1712.00576',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.11179': {'type': 'use',
#   'date': '2017-11-30',
#   'arxiv_id': '1711.11179',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1703.02647': {'type': 'use',
#   'date': '2017-03-08',
#   'arxiv_id': '1703.02647',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.04806': {'type': 'use',
#   'date': '2017-10-13',
#   'arxiv_id': '1710.04806',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.07414': {'type': 'use',
#   'date': '2017-11-20',
#   'arxiv_id': '1711.07414',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.06793': {'type': 'use',
#   'date': '2017-11-18',
#   'arxiv_id': '1711.06793',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.06788': {'type': 'use',
#   'date': '2017-11-18',
#   'arxiv_id': '1711.06788',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.06178': {'type': 'use',
#   'date': '2017-11-16',
#   'arxiv_id': '1711.06178',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.05847': {'type': 'use',
#   'date': '2017-11-15',
#   'arxiv_id': '1711.05847',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.05822': {'type': 'use',
#   'date': '2017-11-15',
#   'arxiv_id': '1711.05822',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.05611': {'type': 'use',
#   'date': '2017-11-15',
#   'arxiv_id': '1711.05611',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.05226': {'type': 'use',
#   'date': '2017-11-14',
#   'arxiv_id': '1711.05226',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.02478': {'type': 'use',
#   'date': '2017-11-07',
#   'arxiv_id': '1711.02478',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.04154': {'type': 'use',
#   'date': '2017-11-11',
#   'arxiv_id': '1711.04154',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1704.00541': {'type': 'use',
#   'date': '2017-04-03',
#   'arxiv_id': '1704.00541',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1711.02368': {'type': 'use',
#   'date': '2017-11-07',
#   'arxiv_id': '1711.02368',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1705.07704': {'type': 'use',
#   'date': '2017-05-22',
#   'arxiv_id': '1705.07704',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.10600': {'type': 'use',
#   'date': '2017-10-29',
#   'arxiv_id': '1710.10600',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1612.08321': {'type': 'use',
#   'date': '2016-12-26',
#   'arxiv_id': '1612.08321',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.05135': {'type': 'use',
#   'date': '2017-10-14',
#   'arxiv_id': '1710.05135',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.05257': {'type': 'use',
#   'date': '2017-10-15',
#   'arxiv_id': '1710.05257',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1710.02924': {'type': 'use',
#   'date': '2017-10-09',
#   'arxiv_id': '1710.02924',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1709.02727': {'type': 'use',
#   'date': '2017-09-08',
#   'arxiv_id': '1709.02727',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1709.07124': {'type': 'use',
#   'date': '2017-09-21',
#   'arxiv_id': '1709.07124',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1709.04764': {'type': 'use',
#   'date': '2017-09-14',
#   'arxiv_id': '1709.04764',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1707.00117': {'type': 'use',
#   'date': '2017-07-01',
#   'arxiv_id': '1707.00117',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1709.03730': {'type': 'use',
#   'date': '2017-09-12',
#   'arxiv_id': '1709.03730',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1709.01919': {'type': 'use',
#   'date': '2017-09-06',
#   'arxiv_id': '1709.01919',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1709.00776': {'type': 'use',
#   'date': '2017-09-03',
#   'arxiv_id': '1709.00776',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.08296': {'type': 'use',
#   'date': '2017-08-28',
#   'arxiv_id': '1708.08296',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1610.01256': {'type': 'use',
#   'date': '2016-10-05',
#   'arxiv_id': '1610.01256',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.06656': {'type': 'use',
#   'date': '2017-08-22',
#   'arxiv_id': '1708.06656',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.05493': {'type': 'use',
#   'date': '2017-08-18',
#   'arxiv_id': '1708.05493',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.04988': {'type': 'use',
#   'date': '2017-08-16',
#   'arxiv_id': '1708.04988',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.03798': {'type': 'use',
#   'date': '2017-08-12',
#   'arxiv_id': '1708.03798',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.03246': {'type': 'use',
#   'date': '2017-08-10',
#   'arxiv_id': '1708.03246',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.01947': {'type': 'use',
#   'date': '2017-08-06',
#   'arxiv_id': '1708.01947',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1708.01519': {'type': 'use',
#   'date': '2017-08-04',
#   'arxiv_id': '1708.01519',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1707.08352': {'type': 'use',
#   'date': '2017-07-26',
#   'arxiv_id': '1707.08352',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1705.07356': {'type': 'use',
#   'date': '2017-05-20',
#   'arxiv_id': '1705.07356',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1707.05635': {'type': 'use',
#   'date': '2017-07-18',
#   'arxiv_id': '1707.05635',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1707.04662': {'type': 'use',
#   'date': '2017-07-14',
#   'arxiv_id': '1707.04662',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.05084': {'type': 'use',
#   'date': '2017-06-12',
#   'arxiv_id': '1706.05084',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.08606': {'type': 'use',
#   'date': '2017-06-26',
#   'arxiv_id': '1706.08606',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.09090': {'type': 'use',
#   'date': '2017-06-28',
#   'arxiv_id': '1706.09090',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.01991': {'type': 'use',
#   'date': '2017-06-06',
#   'arxiv_id': '1706.01991',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.05136': {'type': 'use',
#   'date': '2017-06-16',
#   'arxiv_id': '1706.05136',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.09434': {'type': 'use',
#   'date': '2016-11-28',
#   'arxiv_id': '1611.09434',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1706.00856': {'type': 'use',
#   'date': '2017-06-02',
#   'arxiv_id': '1706.00856',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1705.05603': {'type': 'use',
#   'date': '2017-05-16',
#   'arxiv_id': '1705.05603',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1704.06611': {'type': 'use',
#   'date': '2017-04-21',
#   'arxiv_id': '1704.06611',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1704.05796': {'type': 'use',
#   'date': '2017-04-19',
#   'arxiv_id': '1704.05796',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1612.00385': {'type': 'use',
#   'date': '2016-12-01',
#   'arxiv_id': '1612.00385',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1605.01713': {'type': 'use',
#   'date': '2016-05-05',
#   'arxiv_id': '1605.01713',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1704.02685': {'type': 'use',
#   'date': '2017-04-10',
#   'arxiv_id': '1704.02685',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1604.03605': {'type': 'use',
#   'date': '2016-04-12',
#   'arxiv_id': '1604.03605',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1703.08705': {'type': 'use',
#   'date': '2017-03-25',
#   'arxiv_id': '1703.08705',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1703.08524': {'type': 'use',
#   'date': '2017-03-24',
#   'arxiv_id': '1703.08524',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.03490': {'type': 'use',
#   'date': '2016-06-10',
#   'arxiv_id': '1606.03490',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1702.08608': {'type': 'use',
#   'date': '2017-02-28',
#   'arxiv_id': '1702.08608',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1506.03018': {'type': 'use',
#   'date': '2015-06-09',
#   'arxiv_id': '1506.03018',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.09066': {'type': 'use',
#   'date': '2016-06-29',
#   'arxiv_id': '1606.09066',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1608.05745': {'type': 'use',
#   'date': '2016-08-19',
#   'arxiv_id': '1608.05745',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1702.07405': {'type': 'use',
#   'date': '2017-02-23',
#   'arxiv_id': '1702.07405',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1602.01182': {'type': 'use',
#   'date': '2016-02-03',
#   'arxiv_id': '1602.01182',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1701.06109': {'type': 'use',
#   'date': '2017-01-22',
#   'arxiv_id': '1701.06109',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1701.05644': {'type': 'use',
#   'date': '2017-01-19',
#   'arxiv_id': '1701.05644',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.05545': {'type': 'use',
#   'date': '2016-06-17',
#   'arxiv_id': '1606.05545',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1612.08974': {'type': 'use',
#   'date': '2016-12-28',
#   'arxiv_id': '1612.08974',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1609.00066': {'type': 'use',
#   'date': '2016-08-31',
#   'arxiv_id': '1609.00066',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1612.00542': {'type': 'use',
#   'date': '2016-12-02',
#   'arxiv_id': '1612.00542',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.07100': {'type': 'use',
#   'date': '2016-11-21',
#   'arxiv_id': '1611.07100',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.07579': {'type': 'use',
#   'date': '2016-11-22',
#   'arxiv_id': '1611.07579',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.07429': {'type': 'use',
#   'date': '2016-11-22',
#   'arxiv_id': '1611.07429',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.07115': {'type': 'use',
#   'date': '2016-11-22',
#   'arxiv_id': '1611.07115',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.06800': {'type': 'use',
#   'date': '2016-11-21',
#   'arxiv_id': '1611.06800',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.05722': {'type': 'use',
#   'date': '2016-11-17',
#   'arxiv_id': '1611.05722',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.04967': {'type': 'use',
#   'date': '2016-11-15',
#   'arxiv_id': '1611.04967',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1602.05012': {'type': 'use',
#   'date': '2016-02-16',
#   'arxiv_id': '1602.05012',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1611.00555': {'type': 'use',
#   'date': '2016-11-02',
#   'arxiv_id': '1611.00555',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1610.09778': {'type': 'use',
#   'date': '2016-10-31',
#   'arxiv_id': '1610.09778',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1610.00824': {'type': 'use',
#   'date': '2016-10-04',
#   'arxiv_id': '1610.00824',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1609.06480': {'type': 'use',
#   'date': '2016-09-21',
#   'arxiv_id': '1609.06480',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1609.05294': {'type': 'use',
#   'date': '2016-09-17',
#   'arxiv_id': '1609.05294',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1609.01423': {'type': 'use',
#   'date': '2016-09-06',
#   'arxiv_id': '1609.01423',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1406.1845': {'type': 'use',
#   'date': '2014-06-07',
#   'arxiv_id': '1406.1845',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1608.03995': {'type': 'use',
#   'date': '2016-08-13',
#   'arxiv_id': '1608.03995',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1607.02670': {'type': 'use',
#   'date': '2016-07-09',
#   'arxiv_id': '1607.02670',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1503.07810': {'type': 'use',
#   'date': '2015-03-26',
#   'arxiv_id': '1503.07810',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.09604': {'type': 'use',
#   'date': '2016-06-30',
#   'arxiv_id': '1606.09604',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.08288': {'type': 'use',
#   'date': '2016-06-27',
#   'arxiv_id': '1606.08288',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.05685': {'type': 'use',
#   'date': '2016-06-17',
#   'arxiv_id': '1606.05685',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1604.02416': {'type': 'use',
#   'date': '2016-03-14',
#   'arxiv_id': '1604.02416',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.05672': {'type': 'use',
#   'date': '2016-06-17',
#   'arxiv_id': '1606.05672',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.05390': {'type': 'use',
#   'date': '2016-06-17',
#   'arxiv_id': '1606.05390',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.05386': {'type': 'use',
#   'date': '2016-06-16',
#   'arxiv_id': '1606.05386',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1605.04056': {'type': 'use',
#   'date': '2016-05-13',
#   'arxiv_id': '1605.04056',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1606.03352': {'type': 'use',
#   'date': '2016-06-10',
#   'arxiv_id': '1606.03352',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1511.03796': {'type': 'use',
#   'date': '2015-11-12',
#   'arxiv_id': '1511.03796',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1506.08301': {'type': 'use',
#   'date': '2015-06-27',
#   'arxiv_id': '1506.08301',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1605.07699': {'type': 'use',
#   'date': '2016-05-25',
#   'arxiv_id': '1605.07699',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1605.04934': {'type': 'use',
#   'date': '2016-05-16',
#   'arxiv_id': '1605.04934',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1510.08291': {'type': 'use',
#   'date': '2015-10-28',
#   'arxiv_id': '1510.08291',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1602.03616': {'type': 'use',
#   'date': '2016-02-11',
#   'arxiv_id': '1602.03616',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1604.08201': {'type': 'use',
#   'date': '2016-04-27',
#   'arxiv_id': '1604.08201',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1601.07381': {'type': 'use',
#   'date': '2016-01-26',
#   'arxiv_id': '1601.07381',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1604.04026': {'type': 'use',
#   'date': '2016-04-14',
#   'arxiv_id': '1604.04026',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1603.08704': {'type': 'use',
#   'date': '2016-03-29',
#   'arxiv_id': '1603.08704',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1512.03883': {'type': 'use',
#   'date': '2015-12-12',
#   'arxiv_id': '1512.03883',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1601.06035': {'type': 'use',
#   'date': '2016-01-22',
#   'arxiv_id': '1601.06035',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1510.07786': {'type': 'use',
#   'date': '2015-10-27',
#   'arxiv_id': '1510.07786',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1601.04126': {'type': 'use',
#   'date': '2016-01-16',
#   'arxiv_id': '1601.04126',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1512.07336': {'type': 'use',
#   'date': '2015-12-23',
#   'arxiv_id': '1512.07336',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1512.02406': {'type': 'use',
#   'date': '2015-12-08',
#   'arxiv_id': '1512.02406',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1512.02479': {'type': 'use',
#   'date': '2015-12-08',
#   'arxiv_id': '1512.02479',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1511.07110': {'type': 'use',
#   'date': '2015-11-23',
#   'arxiv_id': '1511.07110',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1511.04775': {'type': 'use',
#   'date': '2015-11-15',
#   'arxiv_id': '1511.04775',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1511.04145': {'type': 'use',
#   'date': '2015-11-13',
#   'arxiv_id': '1511.04145',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1508.04211': {'type': 'use',
#   'date': '2015-08-18',
#   'arxiv_id': '1508.04211',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1507.07955': {'type': 'use',
#   'date': '2015-07-28',
#   'arxiv_id': '1507.07955',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1507.05367': {'type': 'use',
#   'date': '2015-07-20',
#   'arxiv_id': '1507.05367',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1507.01154': {'type': 'use',
#   'date': '2015-07-04',
#   'arxiv_id': '1507.01154',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1506.08251': {'type': 'use',
#   'date': '2015-06-27',
#   'arxiv_id': '1506.08251',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1503.01161': {'type': 'use',
#   'date': '2015-03-03',
#   'arxiv_id': '1503.01161',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1501.07196': {'type': 'use',
#   'date': '2015-01-28',
#   'arxiv_id': '1501.07196',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1502.03466': {'type': 'use',
#   'date': '2015-02-11',
#   'arxiv_id': '1502.03466',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1401.0211': {'type': 'use',
#   'date': '2013-12-31',
#   'arxiv_id': '1401.0211',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1412.5212': {'type': 'use',
#   'date': '2014-12-16',
#   'arxiv_id': '1412.5212',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1412.4940': {'type': 'use',
#   'date': '2014-12-16',
#   'arxiv_id': '1412.4940',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1310.1533': {'type': 'use',
#   'date': '2013-10-06',
#   'arxiv_id': '1310.1533',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1409.7591': {'type': 'use',
#   'date': '2014-09-26',
#   'arxiv_id': '1409.7591',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1408.5246': {'type': 'use',
#   'date': '2014-08-22',
#   'arxiv_id': '1408.5246',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1407.0612': {'type': 'use',
#   'date': '2014-07-02',
#   'arxiv_id': '1407.0612',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1403.1430': {'type': 'use',
#   'date': '2014-03-06',
#   'arxiv_id': '1403.1430',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.07243': {'type': 'use',
#   'date': '2018-06-19',
#   'arxiv_id': '1806.07243',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.07552': {'type': 'use',
#   'date': '2018-06-20',
#   'arxiv_id': '1806.07552',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.07538': {'type': 'use',
#   'date': '2018-06-20',
#   'arxiv_id': '1806.07538',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.08049': {'type': 'use',
#   'date': '2018-06-21',
#   'arxiv_id': '1806.08049',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.08523': {'type': 'use',
#   'date': '2018-06-22',
#   'arxiv_id': '1806.08523',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.09248': {'type': 'use',
#   'date': '2018-06-25',
#   'arxiv_id': '1806.09248',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.08946': {'type': 'use',
#   'date': '2018-06-23',
#   'arxiv_id': '1806.08946',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.10080': {'type': 'use',
#   'date': '2018-06-26',
#   'arxiv_id': '1806.10080',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.09710': {'type': 'use',
#   'date': '2018-06-25',
#   'arxiv_id': '1806.09710',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.10574': {'type': 'use',
#   'date': '2018-06-27',
#   'arxiv_id': '1806.10574',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.10758': {'type': 'use',
#   'date': '2018-06-28',
#   'arxiv_id': '1806.10758',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.11217': {'type': 'use',
#   'date': '2018-06-28',
#   'arxiv_id': '1806.11217',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1806.11216': {'type': 'use',
#   'date': '2018-06-28',
#   'arxiv_id': '1806.11216',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.02910': {'type': 'use',
#   'date': '2018-07-09',
#   'arxiv_id': '1807.02910',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.03418': {'type': 'use',
#   'date': '2018-07-09',
#   'arxiv_id': '1807.03418',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.04427': {'type': 'use',
#   'date': '2018-07-12',
#   'arxiv_id': '1807.04427',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.05351': {'type': 'use',
#   'date': '2018-07-14',
#   'arxiv_id': '1807.05351',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.06843': {'type': 'use',
#   'date': '2018-07-18',
#   'arxiv_id': '1807.06843',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.06722': {'type': 'use',
#   'date': '2018-07-18',
#   'arxiv_id': '1807.06722',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.07279': {'type': 'use',
#   'date': '2018-07-19',
#   'arxiv_id': '1807.07279',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.07155': {'type': 'use',
#   'date': '2018-07-18',
#   'arxiv_id': '1807.07155',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1807.09813': {'type': 'use',
#   'date': '2018-07-25',
#   'arxiv_id': '1807.09813',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.00033': {'type': 'use',
#   'date': '2018-07-31',
#   'arxiv_id': '1808.00033',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.01132': {'type': 'use',
#   'date': '2018-08-03',
#   'arxiv_id': '1808.01132',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.01664': {'type': 'use',
#   'date': '2018-08-05',
#   'arxiv_id': '1808.01664',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.04022': {'type': 'use',
#   'date': '2018-08-12',
#   'arxiv_id': '1808.04022',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.03793': {'type': 'use',
#   'date': '2018-08-11',
#   'arxiv_id': '1808.03793',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.05054': {'type': 'use',
#   'date': '2018-08-15',
#   'arxiv_id': '1808.05054',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.05744': {'type': 'use',
#   'date': '2018-08-17',
#   'arxiv_id': '1808.05744',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.07292': {'type': 'use',
#   'date': '2018-08-22',
#   'arxiv_id': '1808.07292',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.07475': {'type': 'use',
#   'date': '2018-08-22',
#   'arxiv_id': '1808.07475',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1808.09663': {'type': 'use',
#   'date': '2018-08-29',
#   'arxiv_id': '1808.09663',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.01185': {'type': 'use',
#   'date': '2018-09-04',
#   'arxiv_id': '1809.01185',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.01133': {'type': 'use',
#   'date': '2018-09-04',
#   'arxiv_id': '1809.01133',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.03259': {'type': 'use',
#   'date': '2018-09-10',
#   'arxiv_id': '1809.03259',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.05183': {'type': 'use',
#   'date': '2018-09-13',
#   'arxiv_id': '1809.05183',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.07109': {'type': 'use',
#   'date': '2018-09-19',
#   'arxiv_id': '1809.07109',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.08037': {'type': 'use',
#   'date': '2018-09-21',
#   'arxiv_id': '1809.08037',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.09468': {'type': 'use',
#   'date': '2018-09-25',
#   'arxiv_id': '1809.09468',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1809.10680': {'type': 'use',
#   'date': '2018-09-27',
#   'arxiv_id': '1809.10680',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.02125': {'type': 'use',
#   'date': '2018-10-04',
#   'arxiv_id': '1810.02125',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.03234': {'type': 'use',
#   'date': '2018-10-08',
#   'arxiv_id': '1810.03234',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.03947': {'type': 'use',
#   'date': '2018-10-09',
#   'arxiv_id': '1810.03947',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.04538': {'type': 'use',
#   'date': '2018-10-10',
#   'arxiv_id': '1810.04538',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.05436': {'type': 'use',
#   'date': '2018-10-12',
#   'arxiv_id': '1810.05436',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.05420': {'type': 'use',
#   'date': '2018-10-12',
#   'arxiv_id': '1810.05420',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.05741': {'type': 'use',
#   'date': '2018-10-12',
#   'arxiv_id': '1810.05741',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.07091': {'type': 'use',
#   'date': '2018-10-16',
#   'arxiv_id': '1810.07091',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.06891': {'type': 'use',
#   'date': '2018-10-16',
#   'arxiv_id': '1810.06891',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.08113': {'type': 'use',
#   'date': '2018-10-18',
#   'arxiv_id': '1810.08113',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.09092': {'type': 'use',
#   'date': '2018-10-22',
#   'arxiv_id': '1810.09092',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.08744': {'type': 'use',
#   'date': '2018-10-20',
#   'arxiv_id': '1810.08744',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.09648': {'type': 'use',
#   'date': '2018-10-23',
#   'arxiv_id': '1810.09648',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.10053': {'type': 'use',
#   'date': '2018-10-23',
#   'arxiv_id': '1810.10053',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.10708': {'type': 'use',
#   'date': '2018-10-25',
#   'arxiv_id': '1810.10708',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.11580': {'type': 'use',
#   'date': '2018-10-27',
#   'arxiv_id': '1810.11580',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.12456': {'type': 'use',
#   'date': '2018-10-29',
#   'arxiv_id': '1810.12456',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1810.12387': {'type': 'use',
#   'date': '2018-10-29',
#   'arxiv_id': '1810.12387',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.00090': {'type': 'use',
#   'date': '2018-10-31',
#   'arxiv_id': '1811.00090',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.01012': {'type': 'use',
#   'date': '2018-11-02',
#   'arxiv_id': '1811.01012',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.01439': {'type': 'use',
#   'date': '2018-11-04',
#   'arxiv_id': '1811.01439',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.01315': {'type': 'use',
#   'date': '2018-11-04',
#   'arxiv_id': '1811.01315',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.02579': {'type': 'use',
#   'date': '2018-11-06',
#   'arxiv_id': '1811.02579',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.04576': {'type': 'use',
#   'date': '2018-11-12',
#   'arxiv_id': '1811.04576',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.06802': {'type': 'use',
#   'date': '2018-11-16',
#   'arxiv_id': '1811.06802',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.07747': {'type': 'use',
#   'date': '2018-11-19',
#   'arxiv_id': '1811.07747',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.07311': {'type': 'use',
#   'date': '2018-11-18',
#   'arxiv_id': '1811.07311',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.08600': {'type': 'use',
#   'date': '2018-11-21',
#   'arxiv_id': '1811.08600',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.08425': {'type': 'use',
#   'date': '2018-11-20',
#   'arxiv_id': '1811.08425',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.10469': {'type': 'use',
#   'date': '2018-11-21',
#   'arxiv_id': '1811.10469',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.10799': {'type': 'use',
#   'date': '2018-11-27',
#   'arxiv_id': '1811.10799',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.11705': {'type': 'use',
#   'date': '2018-11-28',
#   'arxiv_id': '1811.11705',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.11205': {'type': 'use',
#   'date': '2018-11-27',
#   'arxiv_id': '1811.11205',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.12386': {'type': 'use',
#   'date': '2018-11-29',
#   'arxiv_id': '1811.12386',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.12084': {'type': 'use',
#   'date': '2018-11-29',
#   'arxiv_id': '1811.12084',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1811.12470': {'type': 'use',
#   'date': '2018-11-29',
#   'arxiv_id': '1811.12470',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.00891': {'type': 'use',
#   'date': '2018-12-03',
#   'arxiv_id': '1812.00891',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.02640': {'type': 'use',
#   'date': '2018-12-06',
#   'arxiv_id': '1812.02640',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.02852': {'type': 'use',
#   'date': '2018-12-06',
#   'arxiv_id': '1812.02852',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.02836': {'type': 'use',
#   'date': '2018-12-06',
#   'arxiv_id': '1812.02836',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.04604': {'type': 'use',
#   'date': '2018-12-11',
#   'arxiv_id': '1812.04604',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.08040': {'type': 'use',
#   'date': '2018-12-19',
#   'arxiv_id': '1812.08040',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.07895': {'type': 'use',
#   'date': '2018-12-19',
#   'arxiv_id': '1812.07895',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.07832': {'type': 'use',
#   'date': '2018-12-19',
#   'arxiv_id': '1812.07832',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.08947': {'type': 'use',
#   'date': '2018-12-21',
#   'arxiv_id': '1812.08947',
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/data2text-studio-automated-text-generation': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/visual-interrogation-of-attention-based': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/convolutional-neural-networks-for-authorship': {'type': 'use',
#   'date': '2017-04-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/rotated-word-vector-representations-and-their': {'type': 'use',
#   'date': '2017-09-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/adapting-topic-models-using-lexical': {'type': 'use',
#   'date': '2017-09-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/attentionmesh-simple-effective-and': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/explaining-non-linear-classifier-decisions': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/introspection-for-convolutional-automatic': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/importance-of-self-attention-for-sentiment': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/representation-of-word-meaning-in-the': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/interpretable-structure-induction-via-sparse': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/learning-comment-controversy-prediction-in': {'type': 'use',
#   'date': '2018-10-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/treat-the-system-like-a-human-student': {'type': 'use',
#   'date': '2018-11-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/a-lexicon-based-supervised-attention-model': {'type': 'use',
#   'date': '2018-08-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/multilevel-heuristics-for-rationale-based': {'type': 'use',
#   'date': '2018-08-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/recognizing-humour-using-word-associations': {'type': 'use',
#   'date': '2018-08-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/interpretable-rationale-augmented-charge': {'type': 'use',
#   'date': '2018-08-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/capturing-pragmatic-knowledge-in-article': {'type': 'use',
#   'date': '2016-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/ridge-regression-and-provable-deterministic': {'type': 'use',
#   'date': '2018-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/learning-filter-widths-of-spectral': {'type': 'use',
#   'date': '2018-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/towards-robust-interpretability-with-self': {'type': 'use',
#   'date': '2018-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/group-sparse-additive-machine': {'type': 'use',
#   'date': '2017-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/cross-spectral-factor-analysis': {'type': 'use',
#   'date': '2017-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/examples-are-not-enough-learn-to-criticize': {'type': 'use',
#   'date': '2016-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/learning-deep-parsimonious-representations': {'type': 'use',
#   'date': '2016-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/mind-the-gap-a-generative-approach-to': {'type': 'use',
#   'date': '2015-12-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/interpretable-basis-decomposition-for-visual': {'type': 'use',
#   'date': '2018-09-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/isurvive-an-interpretable-event-time': {'type': 'use',
#   'date': '2017-08-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/nonoverlap-promoting-variable-selection': {'type': 'use',
#   'date': '2018-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/discovering-interpretable-representations-for': {'type': 'use',
#   'date': '2018-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/ultra-large-scale-feature-selection-using': {'type': 'use',
#   'date': '2018-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/inter-and-intra-topic-structure-learning-with': {'type': 'use',
#   'date': '2018-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/oi-vae-output-interpretable-vaes-for': {'type': 'use',
#   'date': '2018-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/guiding-physical-intuition-with-neural': {'type': 'use',
#   'date': '2019-05-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/segen-sample-ensemble-genetic-evolutionary': {'type': 'use',
#   'date': '2019-05-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/pearl-prototype-learning-via-rule-lists': {'type': 'use',
#   'date': '2019-05-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/unlabeled-disentangling-of-gans-with-guided': {'type': 'use',
#   'date': '2019-05-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/parametrized-hierarchical-procedures-for': {'type': 'use',
#   'date': '2018-01-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/tcav-relative-concept-importance-testing-with': {'type': 'use',
#   'date': '2018-01-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/learning-parsimonious-deep-feed-forward': {'type': 'use',
#   'date': '2018-01-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/learning-covariate-specific-embeddings-with': {'type': 'use',
#   'date': '2018-01-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/regularization-neural-networks-via': {'type': 'use',
#   'date': '2018-01-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/transfer-learning-on-manifolds-via-learned': {'type': 'use',
#   'date': '2018-01-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.09681': {'type': 'use',
#   'date': '2018-12-23',
#   'arxiv_id': '1812.09681',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.09355': {'type': 'use',
#   'date': '2018-12-21',
#   'arxiv_id': '1812.09355',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.10924': {'type': 'use',
#   'date': '2018-12-28',
#   'arxiv_id': '1812.10924',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.00563': {'type': 'use',
#   'date': '2019-01-03',
#   'arxiv_id': '1901.00563',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1812.11709': {'type': 'use',
#   'date': '2018-12-31',
#   'arxiv_id': '1812.11709',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.01499': {'type': 'use',
#   'date': '2019-01-06',
#   'arxiv_id': '1901.01499',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.02229': {'type': 'use',
#   'date': '2019-01-08',
#   'arxiv_id': '1901.02229',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.03227': {'type': 'use',
#   'date': '2019-01-10',
#   'arxiv_id': '1901.03227',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.07667': {'type': 'use',
#   'date': '2019-01-23',
#   'arxiv_id': '1901.07667',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.07538': {'type': 'use',
#   'date': '2019-01-21',
#   'arxiv_id': '1901.07538',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.08558': {'type': 'use',
#   'date': '2019-01-20',
#   'arxiv_id': '1901.08558',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.08930': {'type': 'use',
#   'date': '2019-01-23',
#   'arxiv_id': '1901.08930',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.09839': {'type': 'use',
#   'date': '2019-01-28',
#   'arxiv_id': '1901.09839',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.09482': {'type': 'use',
#   'date': '2019-01-28',
#   'arxiv_id': '1901.09482',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.08817': {'type': 'use',
#   'date': '2019-01-25',
#   'arxiv_id': '1901.08817',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.08813': {'type': 'use',
#   'date': '2019-01-25',
#   'arxiv_id': '1901.08813',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.09035': {'type': 'use',
#   'date': '2019-01-25',
#   'arxiv_id': '1901.09035',
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/deep-fisher-kernels-end-to-end-learning-of': {'type': 'use',
#   'date': '2014-06-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/knowledge-acquisition-for-visual-question': {'type': 'use',
#   'date': '2017-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/sparse-exact-pga-on-riemannian-manifolds': {'type': 'use',
#   'date': '2017-10-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.10334': {'type': 'use',
#   'date': '2019-01-29',
#   'arxiv_id': '1901.10334',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.10526': {'type': 'use',
#   'date': '2019-01-29',
#   'arxiv_id': '1901.10526',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1901.11493': {'type': 'use',
#   'date': '2019-01-20',
#   'arxiv_id': '1901.11493',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.00440': {'type': 'use',
#   'date': '2019-02-01',
#   'arxiv_id': '1902.00440',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.00293': {'type': 'use',
#   'date': '2019-02-01',
#   'arxiv_id': '1902.00293',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.00006': {'type': 'use',
#   'date': '2019-01-31',
#   'arxiv_id': '1902.00006',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.01522': {'type': 'use',
#   'date': '2019-02-05',
#   'arxiv_id': '1902.01522',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.02586': {'type': 'use',
#   'date': '2019-02-07',
#   'arxiv_id': '1902.02586',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.02904': {'type': 'use',
#   'date': '2019-02-08',
#   'arxiv_id': '1902.02904',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.03501': {'type': 'use',
#   'date': '2019-02-09',
#   'arxiv_id': '1902.03501',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.03493': {'type': 'use',
#   'date': '2019-02-09',
#   'arxiv_id': '1902.03493',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.04187': {'type': 'use',
#   'date': '2019-02-11',
#   'arxiv_id': '1902.04187',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.06292': {'type': 'use',
#   'date': '2019-02-17',
#   'arxiv_id': '1902.06292',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.06918': {'type': 'use',
#   'date': '2019-02-19',
#   'arxiv_id': '1902.06918',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '1902.07828': {'type': 'use',
#   'date': '2019-02-21',
#   'arxiv_id': '1902.07828',
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/learning-procedural-abstractions-and': {'type': 'use',
# ...
#   'date': '2020-04-29',
#   'arxiv_id': '2004.14841',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2004.14480': {'type': 'use',
#   'date': '2020-04-27',
#   'arxiv_id': '2004.14480',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.00397': {'type': 'use',
#   'date': '2020-05-01',
#   'arxiv_id': '2005.00397',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.00130': {'type': 'use',
#   'date': '2020-04-30',
#   'arxiv_id': '2005.00130',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.01333': {'type': 'use',
#   'date': '2020-05-04',
#   'arxiv_id': '2005.01333',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.00889': {'type': 'use',
#   'date': '2020-05-02',
#   'arxiv_id': '2005.00889',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.00718': {'type': 'use',
#   'date': '2020-05-02',
#   'arxiv_id': '2005.00718',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.00696': {'type': 'use',
#   'date': '2020-05-02',
#   'arxiv_id': '2005.00696',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.00646': {'type': 'use',
#   'date': '2020-05-01',
#   'arxiv_id': '2005.00646',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.01578': {'type': 'use',
#   'date': '2020-04-30',
#   'arxiv_id': '2005.01578',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.02597': {'type': 'use',
#   'date': '2020-05-06',
#   'arxiv_id': '2005.02597',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.02006': {'type': 'use',
#   'date': '2020-05-05',
#   'arxiv_id': '2005.02006',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.03350': {'type': 'use',
#   'date': '2020-05-07',
#   'arxiv_id': '2005.03350',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.03442': {'type': 'use',
#   'date': '2020-05-05',
#   'arxiv_id': '2005.03442',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.05210': {'type': 'use',
#   'date': '2020-05-11',
#   'arxiv_id': '2005.05210',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.05131': {'type': 'use',
#   'date': '2020-05-11',
#   'arxiv_id': '2005.05131',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.05114': {'type': 'use',
#   'date': '2020-05-11',
#   'arxiv_id': '2005.05114',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.04539': {'type': 'use',
#   'date': '2020-05-10',
#   'arxiv_id': '2005.04539',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.04289': {'type': 'use',
#   'date': '2020-05-08',
#   'arxiv_id': '2005.04289',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.06139': {'type': 'use',
#   'date': '2020-05-13',
#   'arxiv_id': '2005.06139',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.06047': {'type': 'use',
#   'date': '2020-05-12',
#   'arxiv_id': '2005.06047',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.07486': {'type': 'use',
#   'date': '2020-05-15',
#   'arxiv_id': '2005.07486',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.08047': {'type': 'use',
#   'date': '2020-05-16',
#   'arxiv_id': '2005.08047',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.09284': {'type': 'use',
#   'date': '2020-05-19',
#   'arxiv_id': '2005.09284',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.09344': {'type': 'use',
#   'date': '2020-05-19',
#   'arxiv_id': '2005.09344',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.10125': {'type': 'use',
#   'date': '2020-05-04',
#   'arxiv_id': '2005.10125',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.10451': {'type': 'use',
#   'date': '2020-05-21',
#   'arxiv_id': '2005.10451',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.10979': {'type': 'use',
#   'date': '2020-05-22',
#   'arxiv_id': '2005.10979',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.10856': {'type': 'use',
#   'date': '2020-05-21',
#   'arxiv_id': '2005.10856',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.12066': {'type': 'use',
#   'date': '2020-05-25',
#   'arxiv_id': '2005.12066',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.11622': {'type': 'use',
#   'date': '2020-05-23',
#   'arxiv_id': '2005.11622',
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/squad2-cr-semi-supervised-annotation-for': {'type': 'use',
#   'date': '2020-05-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/reproducing-a-morphosyntactic-tagger-with-a': {'type': 'use',
#   'date': '2020-05-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.12483': {'type': 'use',
#   'date': '2020-05-26',
#   'arxiv_id': '2005.12483',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.12419': {'type': 'use',
#   'date': '2020-05-25',
#   'arxiv_id': '2005.12419',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.12327': {'type': 'use',
#   'date': '2020-05-25',
#   'arxiv_id': '2005.12327',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.12800': {'type': 'use',
#   'date': '2020-05-23',
#   'arxiv_id': '2005.12800',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.13948': {'type': 'use',
#   'date': '2020-05-28',
#   'arxiv_id': '2005.13948',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.13796': {'type': 'use',
#   'date': '2020-05-28',
#   'arxiv_id': '2005.13796',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.13746': {'type': 'use',
#   'date': '2020-05-28',
#   'arxiv_id': '2005.13746',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.13630': {'type': 'use',
#   'date': '2020-05-27',
#   'arxiv_id': '2005.13630',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.14026': {'type': 'use',
#   'date': '2020-05-27',
#   'arxiv_id': '2005.14026',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2005.13607': {'type': 'use',
#   'date': '2020-05-17',
#   'arxiv_id': '2005.13607',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.00305': {'type': 'use',
#   'date': '2020-05-30',
#   'arxiv_id': '2006.00305',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.01028': {'type': 'use',
#   'date': '2020-06-01',
#   'arxiv_id': '2006.01028',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.01392': {'type': 'use',
#   'date': '2020-06-02',
#   'arxiv_id': '2006.01392',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.01667': {'type': 'use',
#   'date': '2020-05-31',
#   'arxiv_id': '2006.01667',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.02570': {'type': 'use',
#   'date': '2020-06-03',
#   'arxiv_id': '2006.02570',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.02548': {'type': 'use',
#   'date': '2020-06-03',
#   'arxiv_id': '2006.02548',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.02460': {'type': 'use',
#   'date': '2020-06-03',
#   'arxiv_id': '2006.02460',
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/dnu-deep-non-local-unrolling-for': {'type': 'use',
#   'date': '2020-06-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/towards-global-explanations-of-convolutional': {'type': 'use',
#   'date': '2020-06-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/advisable-learning-for-self-driving-vehicles': {'type': 'use',
#   'date': '2020-06-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.03349': {'type': 'use',
#   'date': '2020-06-05',
#   'arxiv_id': '2006.03349',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.04732': {'type': 'use',
#   'date': '2020-06-08',
#   'arxiv_id': '2006.04732',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.03725': {'type': 'use',
#   'date': '2020-06-05',
#   'arxiv_id': '2006.03725',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.03680': {'type': 'use',
#   'date': '2020-06-05',
#   'arxiv_id': '2006.03680',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05964': {'type': 'use',
#   'date': '2020-06-10',
#   'arxiv_id': '2006.05964',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05895': {'type': 'use',
#   'date': '2020-06-10',
#   'arxiv_id': '2006.05895',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05714': {'type': 'use',
#   'date': '2020-06-10',
#   'arxiv_id': '2006.05714',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05669': {'type': 'use',
#   'date': '2020-06-10',
#   'arxiv_id': '2006.05669',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05656': {'type': 'use',
#   'date': '2020-06-10',
#   'arxiv_id': '2006.05656',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05245': {'type': 'use',
#   'date': '2020-06-09',
#   'arxiv_id': '2006.05245',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.04998': {'type': 'use',
#   'date': '2020-06-09',
#   'arxiv_id': '2006.04998',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.05274': {'type': 'use',
#   'date': '2020-06-06',
#   'arxiv_id': '2006.05274',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.06072': {'type': 'use',
#   'date': '2020-06-10',
#   'arxiv_id': '2006.06072',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.07361': {'type': 'use',
#   'date': '2020-06-12',
#   'arxiv_id': '2006.07361',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.07046': {'type': 'use',
#   'date': '2020-06-12',
#   'arxiv_id': '2006.07046',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.06856': {'type': 'use',
#   'date': '2020-06-11',
#   'arxiv_id': '2006.06856',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.06848': {'type': 'use',
#   'date': '2020-06-11',
#   'arxiv_id': '2006.06848',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.08287': {'type': 'use',
#   'date': '2020-06-15',
#   'arxiv_id': '2006.08287',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.07985': {'type': 'use',
#   'date': '2020-06-14',
#   'arxiv_id': '2006.07985',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.07828': {'type': 'use',
#   'date': '2020-06-14',
#   'arxiv_id': '2006.07828',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.07491': {'type': 'use',
#   'date': '2020-06-12',
#   'arxiv_id': '2006.07491',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.09109': {'type': 'use',
#   'date': '2020-06-16',
#   'arxiv_id': '2006.09109',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.09073': {'type': 'use',
#   'date': '2020-06-16',
#   'arxiv_id': '2006.09073',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.09890': {'type': 'use',
#   'date': '2020-06-17',
#   'arxiv_id': '2006.09890',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.09693': {'type': 'use',
#   'date': '2020-06-17',
#   'arxiv_id': '2006.09693',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.09590': {'type': 'use',
#   'date': '2020-06-17',
#   'arxiv_id': '2006.09590',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.09504': {'type': 'use',
#   'date': '2020-06-16',
#   'arxiv_id': '2006.09504',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.11132': {'type': 'use',
#   'date': '2020-06-19',
#   'arxiv_id': '2006.11132',
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/interpreting-twitter-user-geolocation': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/towards-interpretable-clinical-diagnosis-with': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/understanding-attention-for-text': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/interpreting-pretrained-contextualized': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/clinical-coder-assigning-interpretable-icd-10': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/exploring-interpretability-in-event': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/interpretability-and-analysis-in-neural-nlp': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/lexicalization-of-probabilistic-linear': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  'https://paperswithcode.com/paper/word-embeddings-as-tuples-of-feature': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': None,
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.12453': {'type': 'use',
#   'date': '2020-06-22',
#   'arxiv_id': '2006.12453',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.12094': {'type': 'use',
#   'date': '2020-06-22',
#   'arxiv_id': '2006.12094',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.13815': {'type': 'use',
#   'date': '2020-06-02',
#   'arxiv_id': '2006.13815',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.13847': {'type': 'use',
#   'date': '2020-06-24',
#   'arxiv_id': '2006.13847',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.13811': {'type': 'use',
#   'date': '2020-06-24',
#   'arxiv_id': '2006.13811',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.14248': {'type': 'use',
#   'date': '2020-06-25',
#   'arxiv_id': '2006.14248',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.14032': {'type': 'use',
#   'date': '2020-06-24',
#   'arxiv_id': '2006.14032',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.14748': {'type': 'use',
#   'date': '2020-06-26',
#   'arxiv_id': '2006.14748',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.14744': {'type': 'use',
#   'date': '2020-06-26',
#   'arxiv_id': '2006.14744',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.14651': {'type': 'use',
#   'date': '2020-06-25',
#   'arxiv_id': '2006.14651',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.15763': {'type': 'use',
#   'date': '2020-06-29',
#   'arxiv_id': '2006.15763',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.15739': {'type': 'use',
#   'date': '2020-06-28',
#   'arxiv_id': '2006.15739',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.15655': {'type': 'use',
#   'date': '2020-06-28',
#   'arxiv_id': '2006.15655',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.15417': {'type': 'use',
#   'date': '2020-06-27',
#   'arxiv_id': '2006.15417',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.16370': {'type': 'use',
#   'date': '2020-06-29',
#   'arxiv_id': '2006.16370',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.16341': {'type': 'use',
#   'date': '2020-06-29',
#   'arxiv_id': '2006.16341',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.16789': {'type': 'use',
#   'date': '2020-06-27',
#   'arxiv_id': '2006.16789',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.16701': {'type': 'use',
#   'date': '2020-06-30',
#   'arxiv_id': '2006.16701',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2006.16915': {'type': 'use',
#   'date': '2020-06-13',
#   'arxiv_id': '2006.16915',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.00453': {'type': 'use',
#   'date': '2020-07-01',
#   'arxiv_id': '2007.00453',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.00119': {'type': 'use',
#   'date': '2020-06-30',
#   'arxiv_id': '2007.00119',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.00820': {'type': 'use',
#   'date': '2020-07-02',
#   'arxiv_id': '2007.00820',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.01764': {'type': 'use',
#   'date': '2020-07-03',
#   'arxiv_id': '2007.01764',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.01669': {'type': 'use',
#   'date': '2020-07-03',
#   'arxiv_id': '2007.01669',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.01516': {'type': 'use',
#   'date': '2020-07-03',
#   'arxiv_id': '2007.01516',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.01819': {'type': 'use',
#   'date': '2020-07-02',
#   'arxiv_id': '2007.01819',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.01926': {'type': 'use',
#   'date': '2020-07-03',
#   'arxiv_id': '2007.01926',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.02739': {'type': 'use',
#   'date': '2020-07-06',
#   'arxiv_id': '2007.02739',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.02771': {'type': 'use',
#   'date': '2020-07-06',
#   'arxiv_id': '2007.02771',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.03155': {'type': 'use',
#   'date': '2020-07-07',
#   'arxiv_id': '2007.03155',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.04865': {'type': 'use',
#   'date': '2020-07-09',
#   'arxiv_id': '2007.04865',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.04862': {'type': 'use',
#   'date': '2020-07-09',
#   'arxiv_id': '2007.04862',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.04525': {'type': 'use',
#   'date': '2020-07-09',
#   'arxiv_id': '2007.04525',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.06381': {'type': 'use',
#   'date': '2020-07-13',
#   'arxiv_id': '2007.06381',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.06126': {'type': 'use',
#   'date': '2020-07-12',
#   'arxiv_id': '2007.06126',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.05961': {'type': 'use',
#   'date': '2020-07-12',
#   'arxiv_id': '2007.05961',
#   'uses_meth': 1,
#   'uses_data': 0},
#  '2007.05729': {'type': 'use',
#   'date': '2020-07-11',
#   'arxiv_id': '2007.05729',
#   'uses_meth': 1,
#   'uses_data': 0},
#  ...}

# %%
def simple_timeline(record_dict, title):
    def usage_profile_to_category(uses_meth, uses_data):
        if uses_meth and not uses_data:
            return 'meth'
        elif not uses_meth and uses_data:
            return 'data'
        elif uses_meth and uses_data:
            return 'COMBI'
        else:
            return 'none'
    color_mapping = {'intro': 'r', 'use': 'b'}
    x = []
    y = []
    c = []
    labels = []
    for arxiv_id, usage in record_dict.items():
        x.append(
            datetime.datetime.strptime(usage['date'], '%Y-%m-%d')
        )
        y.append(
            usage_profile_to_category(usage['uses_meth'], usage['uses_data'])
        )
        c.append(color_mapping[usage['type']])
        labels.append(arxiv_id)
    
    plt.figure(figsize=(14,4))
    plt.title(title)
    # plt.ylim((-1,len(series)))
    # plt.xlim((-1000, dataset[-1][0]+1000))
    # plt.yticks(range(len(series)), series)
    plt.scatter(x, y, color=c, alpha=0.85) # , s=10
    return plt

# %%
def combi_metrics(record_dict, echo=True):
    def papers_per_month(date_list):
        if len(date_list) == 0:
            return 0
        months = (
            max(date_list) - min(date_list)
        ).days / 30.437
        return len(date_list) / max(months, 1)
        
    combi_dates = []
    data_dates = []
    meth_dates = []
    for arxiv_id, usage in record_dict.items():
        if usage['uses_meth'] == 1 and usage['uses_data'] == 1:
            combi_dates.append(
                datetime.datetime.strptime(usage['date'], '%Y-%m-%d')
            )
        elif usage['uses_data'] == 1:
            data_dates.append(
                datetime.datetime.strptime(usage['date'], '%Y-%m-%d')
            )
        elif usage['uses_meth'] == 1:
            meth_dates.append(
                datetime.datetime.strptime(usage['date'], '%Y-%m-%d')
            )
    if len(data_dates) == 0:  # workaround for metrics
        data_dates.append(
            min(combi_dates)
        )
    if len(meth_dates) == 0:  # workaround for metrics
        meth_dates.append(
            min(combi_dates)
        )
    time_data_to_combi = min(combi_dates) - min(data_dates)
    time_meth_to_combi = min(combi_dates) - min(meth_dates)
    time_delta_data_meth = abs(min(data_dates) - min(meth_dates))
    pre_combi_data_papers = len([
            date for date in data_dates
            if date < min(combi_dates)
    ])
    pre_combi_meth_papers = len([
            date for date in meth_dates
            if date < min(combi_dates)
    ])
    combi_paper_num = len(combi_dates)
    combi_time_span = (max(combi_dates) - min(combi_dates)).days
    combi_ppm_rate = papers_per_month(combi_dates)
    post_combi_data_ppm_rate = papers_per_month([
            date for date in data_dates
            if date > min(combi_dates)
    ])
    post_combi_meth_ppm_rate = papers_per_month([
            date for date in meth_dates
            if date > min(combi_dates)
    ])
    if echo:
        print((
            f'- - - stats - - -\n'
            f'[pre combi]\n'
            f'd→c:\t\t{time_data_to_combi.days} days, {pre_combi_data_papers} papers\n'
            f'm→c:\t\t{time_meth_to_combi.days} days, {pre_combi_meth_papers} papers\n'
            f'|m-d|:\t\t{time_delta_data_meth.days} days\n'
            f'[post combi]\n'
            f'combi #pprs:\t{combi_paper_num}\n'
            f'combi time:\t{combi_time_span}\n'
            f'combi ppr/M:\t{combi_ppm_rate}\n'
            f'data ppr/M:\t{post_combi_data_ppm_rate}\n'
            f'meth ppr/M:\t{post_combi_meth_ppm_rate}\n'
        ))
    return {
        'time_data_to_combi.days':  time_data_to_combi.days,
        'pre_combi_data_papers':    pre_combi_data_papers,
        'time_meth_to_combi.days':  time_meth_to_combi.days,
        'pre_combi_meth_papers':    pre_combi_meth_papers,
        'time_delta_data_meth.days':time_delta_data_meth.days,
        'combi_paper_num':          combi_paper_num,
        'combi_time_span':          combi_time_span,
        'combi_ppm_rate':           combi_ppm_rate,
        'post_combi_data_ppm_rate': post_combi_data_ppm_rate,
        'post_combi_meth_ppm_rate': post_combi_meth_ppm_rate
    }

metrics = combi_metrics(pair_records[random_pair])
# Out:
# - - - stats - - -
# [pre combi]
# d→c:		1602 days, 1050 papers
# m→c:		740 days, 20 papers
# |m-d|:		862 days
# [post combi]
# combi #pprs:	13
# combi time:	1147
# combi ppr/M:	0.3449703574542284
# data ppr/M:	97.62562065972223
# meth ppr/M:	11.898582897033158

# %%
while True:
    random_pair = random.choice(list(pair_records.keys()))
    data_name, meth_name = random_pair.split(' + ')
    if meth_name in [
        'Softmax',
        'Dropout',
        'Residual Connection',
        'Average Pooling',
        'Weight Decay',
        'Convolution',
        'Max Pooling',
        'Adam',
        'Layer Normalization',
        'Batch Normalization',
        '1x1 Convolution',
        'Tanh Activation',
        'Sigmoid Activation',
        'Leaky ReLU',
        'Heatmap',
        'Dense Connections',
        'Softmax',
        'Multi-Head Attention',  # ---
        'Scaled Dot-Product Attention',
        'Gaussian Error Linear Units',
        'Rectified Linear Units',
        'Attention Dropout',
        'Byte Pair Encoding',
        'Linear Warmup With Linear Decay',
        'Label Smoothing',
        'Position-Wise Feed-Forward Layer',
        'Absolute Position Encodings',
        'Global Average Pooling'
    ]:
        continue
    combi_use_count = 0
    for _, usage in pair_records[random_pair].items():
        if usage['uses_meth'] + usage['uses_data'] == 2:
            combi_use_count += 1
    if combi_use_count > 10:
        break
# pprint.pprint(pair_records[random_pair])
plt = simple_timeline(pair_records[random_pair], random_pair)
combi_metrics(pair_records[random_pair])
plt.show()

# more stuff/longer time before combi       -> better
# data/meth start delta                     -> ?
# combi ppr/M                               -> higher=better
# combi ppr/M relative to data/meth ppr/M
#     >1 = mostly used in combination
#     <1 = also used for other stuff
#    <<1 = generally very common method
#                                           -> ?
# rate of frequency also mby important?
# (e.g. in case of sudden boom mby not
#  so interesting)

# extra considerations
# -> more interesting if combi-method not also frequently used for other *similar* datasets
# -> derivatie methods later also used for combi
# Out:
# - - - stats - - -
# [pre combi]
# d→c:		2106 days, 78 papers
# m→c:		354 days, 46 papers
# |m-d|:		1752 days
# [post combi]
# combi #pprs:	14
# combi time:	1245
# combi ppr/M:	0.342263453815261
# data ppr/M:	34.31124025457438
# meth ppr/M:	63.144696825396835

# %%
count = 0
meth_counts = dict()
data_counts = dict()
for pair_key, record_dict in pair_records.items():
    data_name, meth_name = pair_key.split(' + ', maxsplit = 1)
    if meth_name in [
        'Softmax',
        'Dropout',
        'Residual Connection',
        'Average Pooling',
        'Weight Decay',
        'Convolution',
        'Max Pooling',
        'Adam',
        'Layer Normalization',
        'Batch Normalization',
        '1x1 Convolution',
        'Tanh Activation',
        'Sigmoid Activation',
        'Leaky ReLU',
        'Heatmap',
        'Dense Connections',
        'Softmax',
        'Multi-Head Attention',  # ---
        'Scaled Dot-Product Attention',
        'Gaussian Error Linear Units',
        'Rectified Linear Units',
        'Attention Dropout',
        'Byte Pair Encoding',
        'Linear Warmup With Linear Decay',
        'Label Smoothing',
        'Position-Wise Feed-Forward Layer',
        'Absolute Position Encodings',
        'Global Average Pooling'
    ]:
        continue
    combi_use_count = 0
    for _, usage in record_dict.items():
        if usage['uses_meth'] + usage['uses_data'] == 2:
            combi_use_count += 1
    if combi_use_count > 10:
        if data_name not in data_counts:
            data_counts[data_name] = 0
        data_counts[data_name] += 1
        if meth_name not in meth_counts:
            meth_counts[meth_name] = 0
        meth_counts[meth_name] += 1
        count += 1

# %%
dict(sorted(meth_counts.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'WordPiece': 67,
#  'BERT': 66,
#  'Transformer': 50,
#  'Long Short-Term Memory': 42,
#  'Residual Block': 38,
#  'Kaiming Initialization': 31,
#  'Residual Network': 28,
#  'Bottleneck Residual Block': 28,
#  'AutoEncoder': 23,
#  'Generative Adversarial Network': 15,
#  'Cosine Annealing': 15,
#  'Concatenated Skip Connection': 14,
#  'Linear Warmup With Cosine Annealing': 14,
#  'Interpretability': 13,
#  'Feedforward Network': 12,
#  'RoBERTa': 10,
#  'Variational Autoencoder': 10,
#  'Stochastic Gradient Descent': 9,
#  'Discriminative Fine-Tuning': 8,
#  'Bidirectional LSTM': 8,
#  'Graph Convolutional Network': 8,
#  'Depthwise Convolution': 7,
#  'Graph Convolutional Networks': 7,
#  'SentencePiece': 7,
#  'U-Net': 6,
#  'RoIPool': 6,
#  'Dilated Convolution': 6,
#  'DenseNet': 6,
#  'Grouped Convolution': 6,
#  'SGD with Momentum': 6,
#  'Dense Block': 6,
#  'Pointwise Convolution': 6,
#  'R1 Regularization': 6,
#  'Region Proposal Network': 5,
#  'Step Decay': 5,
#  'VGG-16': 5,
#  'RMSProp': 5,
#  'XLNet': 5,
#  'Depthwise Separable Convolution': 5,
#  'VGG': 5,
#  'Normalizing Flows': 5,
#  'Auxiliary Classifier': 5,
#  'Squeeze-and-Excitation Block': 5,
#  'Inverted Residual Block': 5,
#  'Mask R-CNN': 4,
#  'ResNeXt Block': 4,
#  'Q-Learning': 4,
#  'Random Horizontal Flip': 4,
#  'StyleGAN': 4,
#  'Non-Local Block': 4,
#  'AlexNet': 4,
#  'Logistic Regression': 4,
#  'Softplus': 4,
#  'Color Jitter': 4,
#  'Instance Normalization': 4,
#  'Swish': 4,
#  'Non-Local Operation': 4,
#  'Differentiable Architecture Search': 4,
#  'Mixup': 4,
#  'MobileNetV2': 4,
#  'ELMo': 4,
#  'InfoNCE': 4,
#  'Faster R-CNN': 4,
#  'EfficientNet': 4,
#  'GAN Hinge Loss': 4,
#  'CutMix': 4,
#  'Feature Pyramid Network': 4,
#  'AutoAugment': 4,
#  'Random Resized Crop': 4,
#  'Linear Layer': 4,
#  'ResNeXt': 4,
#  'Gated Linear Unit': 4,
#  'Local Response Normalization': 4,
#  'Adaptive Instance Normalization': 4,
#  'GPT-2': 4,
#  'Vision Transformer': 4,
#  'Conditional Random Field': 4,
#  'Spectral Normalization': 4,
#  'RoIAlign': 4,
#  'WideResNet': 3,
#  'Support Vector Machine': 3,
#  'Spectral Clustering': 3,
#  'PointNet': 3,
#  'Diffusion-Convolutional Neural Networks': 3,
#  'Random Gaussian Blur': 3,
#  'Spatial Pyramid Pooling': 3,
#  'FixMatch': 3,
#  'Experience Replay': 3,
#  'Memory Network': 3,
#  'Triplet Loss': 3,
#  'k-Means Clustering': 3,
#  'Fully Convolutional Network': 3,
#  'Attentive Walk-Aggregating Graph Neural Network': 3,
#  'Early Stopping': 3,
#  'Inverse Square Root Schedule': 3,
#  'Contrastive Language-Image Pre-training': 3,
#  'Model-Agnostic Meta-Learning': 3,
#  'VOS': 3,
#  'Mish': 3,
#  'TransE': 3,
#  'Cutout': 3,
#  'T5': 3,
#  'Dot-Product Attention': 3,
#  'Wide Residual Block': 3,
#  'Momentum Contrast': 3,
#  'Adafactor': 3,
#  'Inpainting': 3,
#  'Inception Module': 3,
#  'Cycle Consistency Loss': 2,
#  'Normalized Temperature-scaled Cross Entropy Loss': 2,
#  'Stochastic Depth': 2,
#  'Principal Components Analysis': 2,
#  'Strided Attention': 2,
#  'MobileNetV3': 2,
#  'GraphSAGE': 2,
#  'Hard Swish': 2,
#  'DropBlock': 2,
#  'Differentiable Neural Architecture Search': 2,
#  '3D Convolution': 2,
#  'Two Time-scale Update Rule': 2,
#  'Atrous Spatial Pyramid Pooling': 2,
#  'RetinaNet': 2,
#  'GPT-3': 2,
#  'Sequence to Sequence': 2,
#  'Entropy Regularization': 2,
#  'Non Maximum Suppression': 2,
#  'Conditional Batch Normalization': 2,
#  'Xavier Initialization': 2,
#  'Deep Ensembles': 2,
#  'Focal Loss': 2,
#  'ReLU6': 2,
#  'Fixed Factorized Attention': 2,
#  'Projection Discriminator': 2,
#  'Truncation Trick': 2,
#  'LeNet': 2,
#  'Deep Deterministic Policy Gradient': 2,
#  'BigGAN': 2,
#  'Self-Attention GAN': 2,
#  'Group Normalization': 2,
#  'Autoencoders': 2,
#  'Off-Diagonal Orthogonal Regularization': 2,
#  'Maxout': 2,
#  'Alternating Direction Method of Multipliers': 2,
#  'Bootstrap Your Own Latent': 2,
#  'Siamese Network': 2,
#  'Swin Transformer': 2,
#  'Proximal Policy Optimization': 2,
#  'LAMB': 2,
#  'Gaussian Process': 2,
#  'Clipped Double Q-learning': 2,
#  'GAN Least Squares Loss': 2,
#  'SSD': 2,
#  'ALBERT': 2,
#  'Deep Convolutional GAN': 2,
#  'GoogLeNet': 2,
#  'Random Search': 2,
#  'SAGAN Self-Attention Module': 2,
#  'SimCLR': 2,
#  'Deep Q-Network': 2,
#  'Spatial Attention Module': 1,
#  'Xception': 1,
#  'WaveNet': 1,
#  'FCOS': 1,
#  'Prioritized Experience Replay': 1,
#  'ELECTRA': 1,
#  'Darknet-53': 1,
#  'Switchable Atrous Convolution': 1,
#  'DistilBERT': 1,
#  'Inception-v3 Module': 1,
#  'Soft-NMS': 1,
#  'Weight Demodulation': 1,
#  'ShuffleNet Block': 1,
#  'LARS': 1,
#  'MobileNetV1': 1,
#  'MoCo v2': 1,
#  'Wasserstein GAN': 1,
#  'Twin Delayed Deep Deterministic': 1,
#  'CycleGAN': 1,
#  'Pyramid Pooling Module': 1,
#  'GloVe Embeddings': 1,
#  'Bottom-up Path Augmentation': 1,
#  'Cascade R-CNN': 1,
#  'GPT': 1,
#  'Detection Transformer': 1,
#  'PatchGAN': 1,
#  'Path Length Regularization': 1,
#  'Graph Attention Network': 1,
#  'Data-efficient Image Transformer': 1,
#  'Position-Sensitive RoI Pooling': 1,
#  'Darknet-19': 1,
#  'Region-based Fully Convolutional Network': 1,
#  'Dilated Causal Convolution': 1,
#  'YOLOv3': 1,
#  'Gated Recurrent Unit': 1,
#  'Adaptive Input Representations': 1,
#  'PSPNet': 1,
#  'Target Policy Smoothing': 1,
#  'Transformer-XL': 1,
#  'StyleGAN2': 1,
#  'Mixture of Logistic Distributions': 1,
#  'Deformable Convolution': 1,
#  'Groupwise Point Convolution': 1,
#  'PAFPN': 1,
#  'Variational Dropout': 1,
#  'Inception-v3': 1,
#  'HRNet': 1,
#  'YOLOv2': 1,
#  'Low-Rank Factorization-based Multi-Head Attention': 1,
#  'MLP-Mixer': 1,
#  'RandAugment': 1,
#  'ShuffleNet': 1,
#  'AdaGrad': 1,
#  'CARLA: An Open Urban Driving Simulator': 1,
#  'Colorization': 1,
#  'Affine Coupling': 1,
#  'Channel Shuffle': 1,
#  'Adaptive Softmax': 1,
#  'Gradient Clipping': 1,
#  'Double Q-learning': 1}

# %%
column_names = [
    'pair_key',
    'time_data_to_combi.days',
    'pre_combi_data_papers',
    'time_meth_to_combi.days',
    'pre_combi_meth_papers',
    'time_delta_data_meth.days',
    'combi_paper_num',
    'combi_time_span',
    'combi_ppm_rate',
    'post_combi_data_ppm_rate',
    'post_combi_meth_ppm_rate'
]
df_combi_metrics = pd.DataFrame(columns=column_names)
for pair_key, record_dict in pair_records.items():
    metrics = combi_metrics(record_dict, echo=False)
    metrics['pair_key'] = pair_key
    df_add = pd.DataFrame(metrics, index=[0])
    df_combi_metrics = df_combi_metrics.append(df_add.copy())

# %%
df_combi_metrics.fillna(0).describe()
# Out:
#        time_data_to_combi.days  pre_combi_data_papers  \
# count             53524.000000           53524.000000
# mean               1168.858138             159.705833
# std                1091.164638             583.626450
# min               -2794.000000               0.000000
# 25%                 344.000000               2.000000
# 50%                 971.000000              14.000000
# 75%                1795.000000              65.000000
# max                6853.000000            7389.000000
#
#        time_meth_to_combi.days  pre_combi_meth_papers  \
# count             53524.000000           53524.000000
# mean               1510.748449            1163.776455
# std                1140.604150            1765.916891
# min               -3067.000000               0.000000
# 25%                 729.000000              28.000000
# 50%                1404.000000             266.000000
# 75%                2116.000000            1673.000000
# max               10007.000000           10245.000000
#
#        time_delta_data_meth.days  combi_paper_num  combi_time_span  \
# count               53524.000000     53524.000000     53524.000000
# mean                 1345.827872         4.382539       283.793513
# std                  1071.235684        19.947702       488.280843
# min                     0.000000         1.000000         0.000000
# 25%                   531.000000         1.000000         0.000000
# 50%                  1107.000000         1.000000         0.000000
# 75%                  1901.000000         3.000000       430.000000
# max                  9739.000000       983.000000      3999.000000
#
#        combi_ppm_rate  post_combi_data_ppm_rate  post_combi_meth_ppm_rate
# count    53524.000000              53524.000000              53524.000000
# mean         0.785285                 10.283671                 85.084585
# std          0.504787                 30.466287                 98.101424
# min          0.019530                  0.000000                  0.000000
# 25%          0.336786                  0.652221                  4.490588
# 50%          1.000000                  1.665535                 41.792937
# 75%          1.000000                  4.905984                137.176020
# max         11.657761                530.745188                437.774723

# %%
for col_name in df_combi_metrics.columns[1:]:
    # df_combi_metrics[col_name].plot(kind='hist', log=True, bins=50, figsize=(15,5))
    df_combi_metrics[col_name].hist(bins=50, figsize=(15,5))
    _ = plt.title(col_name)
    plt.show()

# %%
df_combi_metrics.sort_values(
    by=[
        'time_data_to_combi.days',
        'time_meth_to_combi.days',
        'pre_combi_meth_papers'
    ],
    ascending=[
        False,
        False,
        False
    ]
).head(50)
# Out:
#                                             pair_key time_data_to_combi.days  \
# 0        20 Newsgroups + Graph Convolutional Network                    6853
# 0              CoNLL-2003 + Packed Levitated Markers                    6668
# 0                  CoNLL-2003 + Auxiliary Classifier                    6565
# 0                  CoNLL-2003 + Sequence to Sequence                    6565
# 0  CoNLL-2003 + Early exiting using confidence me...                    6560
# 0                            CoNLL-2003 + DistilBERT                    6560
# 0                                   PROTEINS + Mixup                    6528
# 0                   CoNLL-2003 + Batch Normalization                    6520
# 0                        CoNLL-2003 + Residual Block                    6520
# 0          CoNLL-2003 + Segregated Attention Network                    6520
# 0                      CoNLL-2003 + Visual Attention                    6520
# 0                               CoNLL-2003 + AdaGrad                    6515
# 0                              CoNLL-2003 + ncMUFCMU                    6515
# 0       20 Newsgroups + Linear Discriminant Analysis                    6454
# 0                            20 Newsgroups + Softmax                    6454
# 0                  20 Newsgroups + Dense Connections                    6454
# 0                       20 Newsgroups + Weight Decay                    6454
# 0            20 Newsgroups + Variational Autoencoder                    6454
# 0                               20 Newsgroups + Adam                    6454
# 0        20 Newsgroups + Gaussian Error Linear Units                    6454
# 0                20 Newsgroups + Layer Normalization                    6454
# 0                          20 Newsgroups + WordPiece                    6454
# 0               20 Newsgroups + Multi-Head Attention                    6454
# 0       20 Newsgroups + Scaled Dot-Product Attention                    6454
# 0    20 Newsgroups + Linear Warmup With Linear Decay                    6454
# 0                  20 Newsgroups + Attention Dropout                    6454
# 0                               20 Newsgroups + BERT                    6454
# 0        20 Newsgroups + Contextualized Topic Models                    6454
# 0                            CoNLL-2003 + Focal Loss                    6438
# 0                   CoNLL-2003 + Monte Carlo Dropout                    6432
# 0                               CoNLL-2003 + Adapter                    6421
# 0                               CoNLL-2003 + RoBERTa                    6384
# 0                          CoNLL 2002 + Linear Layer                    6364
# 0                       CoNLL 2002 + Label Smoothing                    6364
# 0      CoNLL 2002 + Position-Wise Feed-Forward Layer                    6364
# 0                           CoNLL 2002 + Transformer                    6364
# 0           CoNLL 2002 + Absolute Position Encodings                    6364
# 0  PROTEINS + Attentive Walk-Aggregating Graph Ne...                    6357
# 0              CoNLL 2002 + Conditional Random Field                    6330
# 0                CoNLL 2002 + Entropy Regularization                    6330
# 0                CoNLL-2003 + Entropy Regularization                    6330
# 0          CoNLL-2003 + Proximal Policy Optimization                    6330
# 0          CoNLL 2002 + Proximal Policy Optimization                    6330
# 0            CoNLL-2003 + Neural Architecture Search                    6330
# 0            CoNLL 2002 + Neural Architecture Search                    6330
# 0                         CoNLL 2002 + SentencePiece                    6330
# 0                         CoNLL-2003 + SentencePiece                    6330
# 0                                 CoNLL-2003 + XLNet                    6330
# 0                                 CoNLL 2002 + XLNet                    6330
# 0                                 CoNLL-2003 + Mixup                    6325
#
#   pre_combi_data_papers time_meth_to_combi.days pre_combi_meth_papers  \
# 0                     9                    1706                   378
# 0                   329                       0                     0
# 0                   301                    3105                   237
# 0                   301                    2457                   367
# 0                   297                    1360                    14
# 0                   297                     604                    35
# 0                   149                    1315                   153
# 0                   287                    2258                  2848
# 0                   287                    2187                  1463
# 0                   287                       0                     0
# 0                   287                      -7                     0
# 0                   282                    2840                    81
# 0                   282                       0                     0
# 0                     7                    5576                   258
# 0                     7                    3781                  3586
# 0                     7                    2685                  2765
# 0                     7                    2685                   965
# 0                     7                    2301                   328
# 0                     7                    1934                  1823
# 0                     7                    1381                   773
# 0                     7                    1357                  1501
# 0                     7                    1290                   715
# 0                     7                    1031                  1498
# 0                     7                    1031                  1477
# 0                     7                     869                   716
# 0                     7                     667                   760
# 0                     7                     545                   709
# 0                     7                      -8                     0
# 0                   271                    1268                   167
# 0                   270                    2055                    47
# 0                   269                      -3                     0
# 0                   264                     496                   171
# 0                    41                    1969                    99
# 0                    41                    1901                  1461
# 0                    41                    1250                  1350
# 0                    41                    1250                  1343
# 0                    41                    1250                  1343
# 0                   121                      31                    46
# 0                    39                    4331                   324
# 0                    39                    1710                   168
# 0                   241                    1710                   168
# 0                   241                    1178                    92
# 0                    39                    1178                    92
# 0                   241                    1177                    11
# 0                    39                    1177                    11
# 0                    39                     783                    85
# 0                   241                     783                    85
# 0                   241                     479                    59
# 0                    39                     479                    59
# 0                   239                    1076                    84
#
#   time_delta_data_meth.days combi_paper_num combi_time_span  combi_ppm_rate  \
# 0                      5147               1               0        1.000000
# 0                      6668               1               0        1.000000
# 0                      3460               1               0        1.000000
# 0                      4108               1               0        1.000000
# 0                      5200               1               0        1.000000
# 0                      5956               1               0        1.000000
# 0                      5213               1               0        1.000000
# 0                      4262               1               0        1.000000
# 0                      4333               1               0        1.000000
# 0                      6520               1               0        1.000000
# 0                      6527               1               0        1.000000
# 0                      3675               1               0        1.000000
# 0                      6515               1               0        1.000000
# 0                       878               1               0        1.000000
# 0                      2673               2             399        0.152566
# 0                      3769               2             399        0.152566
# 0                      3769               2             399        0.152566
# 0                      4153               1               0        1.000000
# 0                      4520               2             399        0.152566
# 0                      5073               2             399        0.152566
# 0                      5097               2             399        0.152566
# 0                      5164               2             399        0.152566
# 0                      5423               2             399        0.152566
# 0                      5423               2             399        0.152566
# 0                      5585               2             399        0.152566
# 0                      5787               2             399        0.152566
# 0                      5909               2             399        0.152566
# 0                      6462               1               0        1.000000
# 0                      5170               1               0        1.000000
# 0                      4377               1               0        1.000000
# 0                      6424               2              97        0.627567
# 0                      5888               2             160        0.380462
# 0                      4395               1               0        1.000000
# 0                      4463               1               0        1.000000
# 0                      5114               1               0        1.000000
# 0                      5114               1               0        1.000000
# 0                      5114               1               0        1.000000
# 0                      6326               2             328        0.185591
# 0                      1999               1               0        1.000000
# 0                      4620               1               0        1.000000
# 0                      4620               1               0        1.000000
# 0                      5152               1               0        1.000000
# 0                      5152               1               0        1.000000
# 0                      5153               1               0        1.000000
# 0                      5153               1               0        1.000000
# 0                      5547               1               0        1.000000
# 0                      5547               1               0        1.000000
# 0                      5851               1               0        1.000000
# 0                      5851               1               0        1.000000
# 0                      5249               1               0        1.000000
#
#    post_combi_data_ppm_rate  post_combi_meth_ppm_rate
# 0                  1.396193                 16.781481
# 0                 15.505642                  0.000000
# 0                 10.535885                  5.321154
# 0                 10.535885                 10.145667
# 0                 11.294233                  3.000000
# 0                 11.294233                  4.133420
# 0                  5.570170                 11.721081
# 0                 10.448522                 86.068263
# 0                 10.448522                 38.792255
# 0                 10.448522                  0.000000
# 0                 10.448522                  4.218990
# 0                 11.040873                  3.462892
# 0                 11.040873                  0.000000
# 0                  0.432168                  4.086947
# 0                  0.370430                297.294048
# 0                  0.370430                287.928817
# 0                  0.370430                134.268556
# 0                  0.432168                 18.106113
# 0                  0.370430                238.657297
# 0                  0.370430                140.582520
# 0                  0.370430                231.737432
# 0                  0.370430                116.718823
# 0                  0.370430                234.130769
# 0                  0.370430                230.228590
# 0                  0.370430                115.880627
# 0                  0.370430                133.587522
# 0                  0.370430                112.590885
# 0                  0.432168                  0.330837
# 0                  9.758427                  7.421035
# 0                  9.216838                  4.127051
# 0                  9.026145                  3.779091
# 0                  8.317619                 16.602000
# 0                  0.908567                  7.217917
# 0                  0.908567                116.508844
# 0                  0.908567                112.608515
# 0                  0.908567                110.604399
# 0                  0.908567                110.438077
# 0                  5.088539                 25.944792
# 0                  1.034686                  4.471415
# 0                  1.034686                  6.289278
# 0                  8.965938                  6.289278
# 0                  8.965938                  4.523383
# 0                  1.034686                  4.523383
# 0                  8.965938                  2.123512
# 0                  1.034686                  2.123512
# 0                  1.034686                 12.174800
# 0                  8.965938                 12.174800
# 0                  8.965938                  4.860359
# 0                  1.034686                  4.860359
# 0                  9.061397                  9.892025
